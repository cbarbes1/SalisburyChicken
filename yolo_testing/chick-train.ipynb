# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.yaml")  # build a new model from YAML
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolo11n.yaml").load("yolo11n.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="datasets/chick-data/data.yaml", epochs=30, imgsz=640)
# Out:
# Transferred 499/499 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.3.27 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.4 🚀 Python-3.12.7 torch-2.4.1+cu121 CPU (Intel Core(TM) i9-14900HX)
# ...

# %%
# Out:
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7fe0345c89b0>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
# ...

# %%
model = YOLO('runs/detect/train12/weights/best.pt')
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics 8.3.4 🚀 Python-3.12.6 torch-2.4.1+cu121 CPU (Intel Core(TM) i9-14900HX)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/usboot/CodeZone/repos/SalisburyChicken/yolo_testing/datasets/chick-data/valid/labels.cache... 1 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1/1 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  5.76it/s]
#                    all          1         30     0.0833      0.833      0.619      0.267

# %%
results = model('chicks.jpg')

results[0].show()
# Out:
# image 1/1 /home/usboot/CodeZone/repos/SalisburyChicken/yolo_testing/chicks.jpg: 640x640 8 chickss, 55.9ms
# Speed: 2.9ms preprocess, 55.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
results = model('/home/usboot/CodeZone/repos/SalisburyChicken/yolo_testing/datasets/chick-data/test/images/val1_jpg.rf.3fad4955ad32a8753041acd803dbe4d7.jpg')

results[0].show()
# Out:
# image 1/1 /home/usboot/CodeZone/repos/SalisburyChicken/yolo_testing/datasets/chick-data/test/images/val1_jpg.rf.3fad4955ad32a8753041acd803dbe4d7.jpg: 640x640 1 chicks, 101.7ms
# Speed: 2.4ms preprocess, 101.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
